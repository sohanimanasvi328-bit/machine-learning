# %% [markdown]
# # Tutorial : Covid 19 Prediction using Artificial Neural Networks

# %% [markdown]
# Dataset: [Covid 19 Chest X-ray dataset](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
#
#
# A team of researchers from Qatar University, Doha, Qatar, and the University of Dhaka, Bangladesh along with their collaborators from Pakistan and Malaysia in collaboration with medical doctors have created a database of chest X-ray images for COVID-19 positive cases along with Normal and Viral Pneumonia images. This COVID-19, normal, and other lung infection dataset is released in stages. In the first release, we have released 219 COVID-19, 1341 normal, and 1345 viral pneumonia chest X-ray (CXR) images. In the first update, we have increased the COVID-19 class to 1200 CXR images. In the 2nd update, we have increased the database to 3616 COVID-19 positive cases along with 10,192 Normal, 6012 Lung Opacity (Non-COVID lung infection), and 1345 Viral Pneumonia images. We will continue to update this database as soon as we have new x-ray images for COVID-19 pneumonia patients.

# %% [markdown]
# **1. Mount the Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **2. Move to the place where data resides**

# %%
# %cd /content/drive/MyDrive/CSIT12025/
# Out:
# /content/drive/MyDrive/CSIT12025

# %%
# !ls
# Out:
# covid_dataset.zip

# %% [markdown]
# **3. Unziping the dataset**

# %%
# !pip install unzip
# Out:
# Collecting unzip
#   Downloading unzip-1.0.0.tar.gz (704 bytes)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: unzip
#   Building wheel for unzip (setup.py) ... done
#   Created wheel for unzip: filename=unzip-1.0.0-py3-none-any.whl size=1281 sha256=9af8304f2e16594f9debc9a4279495c73fb1db7022a8ae7b92d415d5a2981c4b
#   Stored in directory: /root/.cache/pip/wheels/fb/5b/81/0f3e1e533b52883f88ab978178c15627a4fce4c13f74911dce
# Successfully built unzip
# Installing collected packages: unzip
# Successfully installed unzip-1.0.0

# %%
# !unzip covid_dataset.zip
# Out:
# Archive:  covid_dataset.zip
#    creating: covid_dataset/
#    creating: covid_dataset/COVID/
#   inflating: covid_dataset/COVID/COVID-1.png
#   inflating: covid_dataset/COVID/COVID-10.png
#   inflating: covid_dataset/COVID/COVID-11.png
#   inflating: covid_dataset/COVID/COVID-12.png
#   inflating: covid_dataset/COVID/COVID-13.png
#   inflating: covid_dataset/COVID/COVID-14.png
#   inflating: covid_dataset/COVID/COVID-15.png
#   inflating: covid_dataset/COVID/COVID-16.png
#   inflating: covid_dataset/COVID/COVID-17.png
#   inflating: covid_dataset/COVID/COVID-18.png
#   inflating: covid_dataset/COVID/COVID-19.png
#   inflating: covid_dataset/COVID/COVID-2.png
#   inflating: covid_dataset/COVID/COVID-20.png
#   inflating: covid_dataset/COVID/COVID-21.png
#   inflating: covid_dataset/COVID/COVID-22.png
#   inflating: covid_dataset/COVID/COVID-23.png
#   inflating: covid_dataset/COVID/COVID-24.png
#   inflating: covid_dataset/COVID/COVID-25.png
#   inflating: covid_dataset/COVID/COVID-26.png
#   inflating: covid_dataset/COVID/COVID-27.png
#   inflating: covid_dataset/COVID/COVID-28.png
#   inflating: covid_dataset/COVID/COVID-29.png
#   inflating: covid_dataset/COVID/COVID-3.png
#   inflating: covid_dataset/COVID/COVID-30.png
#   inflating: covid_dataset/COVID/COVID-31.png
#   inflating: covid_dataset/COVID/COVID-32.png
#   inflating: covid_dataset/COVID/COVID-33.png
#   inflating: covid_dataset/COVID/COVID-34.png
#   inflating: covid_dataset/COVID/COVID-35.png
#   inflating: covid_dataset/COVID/COVID-36.png
#   inflating: covid_dataset/COVID/COVID-37.png
#   inflating: covid_dataset/COVID/COVID-38.png
#   inflating: covid_dataset/COVID/COVID-39.png
#   inflating: covid_dataset/COVID/COVID-4.png
#   inflating: covid_dataset/COVID/COVID-40.png
#   inflating: covid_dataset/COVID/COVID-41.png
#   inflating: covid_dataset/COVID/COVID-42.png
#   inflating: covid_dataset/COVID/COVID-43.png
#   inflating: covid_dataset/COVID/COVID-44.png
#   inflating: covid_dataset/COVID/COVID-45.png
#   inflating: covid_dataset/COVID/COVID-46.png
#   inflating: covid_dataset/COVID/COVID-47.png
#   inflating: covid_dataset/COVID/COVID-48.png
#   inflating: covid_dataset/COVID/COVID-49.png
#   inflating: covid_dataset/COVID/COVID-5.png
#   inflating: covid_dataset/COVID/COVID-50.png
#   inflating: covid_dataset/COVID/COVID-6.png
#   inflating: covid_dataset/COVID/COVID-7.png
#   inflating: covid_dataset/COVID/COVID-8.png
#   inflating: covid_dataset/COVID/COVID-9.png
#    creating: covid_dataset/Normal/
#   inflating: covid_dataset/Normal/Normal-1.png
#   inflating: covid_dataset/Normal/Normal-10.png
#   inflating: covid_dataset/Normal/Normal-11.png
#   inflating: covid_dataset/Normal/Normal-12.png
#   inflating: covid_dataset/Normal/Normal-13.png
#   inflating: covid_dataset/Normal/Normal-14.png
#   inflating: covid_dataset/Normal/Normal-15.png
#   inflating: covid_dataset/Normal/Normal-16.png
#   inflating: covid_dataset/Normal/Normal-17.png
#   inflating: covid_dataset/Normal/Normal-18.png
#   inflating: covid_dataset/Normal/Normal-19.png
#   inflating: covid_dataset/Normal/Normal-2.png
#   inflating: covid_dataset/Normal/Normal-20.png
#   inflating: covid_dataset/Normal/Normal-21.png
#   inflating: covid_dataset/Normal/Normal-22.png
#   inflating: covid_dataset/Normal/Normal-23.png
#   inflating: covid_dataset/Normal/Normal-24.png
#   inflating: covid_dataset/Normal/Normal-25.png
#   inflating: covid_dataset/Normal/Normal-26.png
#   inflating: covid_dataset/Normal/Normal-27.png
#   inflating: covid_dataset/Normal/Normal-28.png
#   inflating: covid_dataset/Normal/Normal-29.png
#   inflating: covid_dataset/Normal/Normal-3.png
#   inflating: covid_dataset/Normal/Normal-30.png
#   inflating: covid_dataset/Normal/Normal-31.png
#   inflating: covid_dataset/Normal/Normal-32.png
#   inflating: covid_dataset/Normal/Normal-33.png
#   inflating: covid_dataset/Normal/Normal-34.png
#   inflating: covid_dataset/Normal/Normal-35.png
#   inflating: covid_dataset/Normal/Normal-36.png
#   inflating: covid_dataset/Normal/Normal-37.png
#   inflating: covid_dataset/Normal/Normal-38.png
#   inflating: covid_dataset/Normal/Normal-39.png
#   inflating: covid_dataset/Normal/Normal-4.png
#   inflating: covid_dataset/Normal/Normal-40.png
#   inflating: covid_dataset/Normal/Normal-41.png
#   inflating: covid_dataset/Normal/Normal-42.png
#   inflating: covid_dataset/Normal/Normal-43.png
#   inflating: covid_dataset/Normal/Normal-44.png
#   inflating: covid_dataset/Normal/Normal-45.png
#   inflating: covid_dataset/Normal/Normal-46.png
#   inflating: covid_dataset/Normal/Normal-47.png
#   inflating: covid_dataset/Normal/Normal-48.png
#   inflating: covid_dataset/Normal/Normal-49.png
#   inflating: covid_dataset/Normal/Normal-5.png
#   inflating: covid_dataset/Normal/Normal-50.png
#   inflating: covid_dataset/Normal/Normal-6.png
#   inflating: covid_dataset/Normal/Normal-7.png
#   inflating: covid_dataset/Normal/Normal-8.png
#   inflating: covid_dataset/Normal/Normal-9.png
#    creating: covid_dataset/Viral Pneumonia/
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-1.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-10.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-11.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-12.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-13.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-14.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-15.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-16.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-17.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-18.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-19.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-2.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-20.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-21.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-22.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-23.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-24.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-25.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-26.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-27.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-28.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-29.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-3.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-30.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-31.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-32.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-33.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-34.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-35.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-36.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-37.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-38.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-39.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-4.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-40.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-41.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-42.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-43.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-44.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-45.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-46.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-47.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-48.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-49.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-5.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-50.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-6.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-7.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-8.png
#   inflating: covid_dataset/Viral Pneumonia/Viral Pneumonia-9.png

# %% [markdown]
# **4. Install split folder python package**
#
# https://pypi.org/project/split-folders/

# %%
# !pip install split_folders
# Out:
# Collecting split_folders
#   Downloading split_folders-0.6.1-py3-none-any.whl.metadata (11 kB)
# Downloading split_folders-0.6.1-py3-none-any.whl (13 kB)
# Installing collected packages: split_folders
# Successfully installed split_folders-0.6.1

# %% [markdown]
# **5. Splitting the data in training, testing and validation set**

# %%
import splitfolders
splitfolders.ratio("covid_dataset", output="split", seed=1337, ratio=(.8, .1, .1), group_prefix=None)
# Out:
# Copying files: 150 files [00:01, 82.53 files/s]

# %% [markdown]
# **6. Loading the dataset with normalization in batches**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Normalize training and validation data in the range of 0 to 1
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# Read the training sample and set the batch size
train_generator = train_datagen.flow_from_directory(
        'split/train/',
        target_size=(128, 128),
        batch_size=8,
        seed=100,
        class_mode='categorical')

# Read Validation data from directory and define target size with batch size
validation_generator = validation_datagen.flow_from_directory(
        'split/val/',
        target_size=(128, 128),
        batch_size=8,
        class_mode='categorical',
        seed=1000,
        shuffle=False)

test_generator = test_datagen.flow_from_directory(
        'split/test/',
        target_size=(128, 128),
        batch_size=8,
        seed=500,
        class_mode='categorical',
        shuffle=False)
# Out:
# Found 120 images belonging to 3 classes.
# Found 15 images belonging to 3 classes.
# Found 15 images belonging to 3 classes.

# %% [markdown]
# **7. Model Building**

# %%
from tensorflow import keras
from tensorflow.keras import layers
inputs = keras.Input(shape=(128, 128,3))
x = layers.Flatten()(inputs)
x = layers.Dense(32, activation="relu")(x)
x = layers.Dense(64, activation='relu')(x)
outputs = layers.Dense(3, activation="softmax")(x)
model = keras.Model(inputs, outputs)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 49152)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │     1,572,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,575,203 (6.01 MB)
#  Trainable params: 1,575,203 (6.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **8. Model Compilation and Training**

# %%
from tensorflow.keras.optimizers import Adam

adam = Adam(learning_rate=0.001)
# We are going to use accuracy metrics and cross entropy loss as performance parameters
model.compile(adam, loss='categorical_crossentropy', metrics=['accuracy'])  # Use 'accuracy'
# Train the model
history = model.fit(train_generator,
      steps_per_epoch=int(train_generator.samples / train_generator.batch_size),  # Convert to int
      epochs=100,
      validation_data=validation_generator,
      validation_steps=int(validation_generator.samples / validation_generator.batch_size),  # Convert to int
      verbose=1)
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5000 - loss: 2.2682 - val_accuracy: 0.3750 - val_loss: 1.6560
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5917 - loss: 0.8492 - val_accuracy: 0.3750 - val_loss: 0.8228
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6667 - loss: 0.5823 - val_accuracy: 0.5000 - val_loss: 0.6299
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7917 - loss: 0.5133 - val_accuracy: 0.8750 - val_loss: 0.3371
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7917 - loss: 0.4738 - val_accuracy: 0.8750 - val_loss: 0.2912
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7917 - loss: 0.4220 - val_accuracy: 0.8750 - val_loss: 0.3139
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8667 - loss: 0.3544 - val_accuracy: 1.0000 - val_loss: 0.2812
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.8833 - loss: 0.2797 - val_accuracy: 0.7500 - val_loss: 0.2869
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8833 - loss: 0.3337 - val_accuracy: 0.8750 - val_loss: 0.2432
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.8333 - loss: 0.3261 - val_accuracy: 0.6250 - val_loss: 0.9603
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.8333 - loss: 0.4163 - val_accuracy: 0.8750 - val_loss: 0.2494
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7750 - loss: 0.5225 - val_accuracy: 0.5000 - val_loss: 1.0453
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7750 - loss: 0.5543 - val_accuracy: 0.8750 - val_loss: 0.2852
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8417 - loss: 0.3539 - val_accuracy: 0.7500 - val_loss: 0.5605
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8500 - loss: 0.2985 - val_accuracy: 0.8750 - val_loss: 0.2630
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.9083 - loss: 0.2287 - val_accuracy: 1.0000 - val_loss: 0.2128
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9417 - loss: 0.1890 - val_accuracy: 0.7500 - val_loss: 0.2886
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9250 - loss: 0.2055 - val_accuracy: 0.8750 - val_loss: 0.2435
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9083 - loss: 0.2165 - val_accuracy: 1.0000 - val_loss: 0.1917
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9417 - loss: 0.1339 - val_accuracy: 0.8750 - val_loss: 0.1829
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.9500 - loss: 0.1485 - val_accuracy: 0.7500 - val_loss: 0.3122
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9583 - loss: 0.1064 - val_accuracy: 0.7500 - val_loss: 0.6398
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8833 - loss: 0.2731 - val_accuracy: 1.0000 - val_loss: 0.1467
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9417 - loss: 0.1425 - val_accuracy: 0.7500 - val_loss: 0.6150
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.9000 - loss: 0.1871 - val_accuracy: 0.8750 - val_loss: 0.1840
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.9250 - loss: 0.2169 - val_accuracy: 1.0000 - val_loss: 0.1012
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.8917 - loss: 0.2133 - val_accuracy: 0.7500 - val_loss: 0.9041
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9417 - loss: 0.1403 - val_accuracy: 0.7500 - val_loss: 0.8183
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9583 - loss: 0.0997 - val_accuracy: 1.0000 - val_loss: 0.1020
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9833 - loss: 0.0661 - val_accuracy: 0.8750 - val_loss: 0.1210
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9500 - loss: 0.1096 - val_accuracy: 0.7500 - val_loss: 1.1395
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9583 - loss: 0.1248 - val_accuracy: 0.7500 - val_loss: 0.3645
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8583 - loss: 0.3294 - val_accuracy: 0.7500 - val_loss: 1.4166
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8917 - loss: 0.2510 - val_accuracy: 0.7500 - val_loss: 0.3045
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9500 - loss: 0.1493 - val_accuracy: 1.0000 - val_loss: 0.1152
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9917 - loss: 0.0532 - val_accuracy: 0.8750 - val_loss: 0.2787
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9917 - loss: 0.0505 - val_accuracy: 0.8750 - val_loss: 0.2554
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.9750 - loss: 0.0861 - val_accuracy: 1.0000 - val_loss: 0.1073
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9667 - loss: 0.0980 - val_accuracy: 0.7500 - val_loss: 0.5934
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8750 - loss: 0.3333 - val_accuracy: 0.8750 - val_loss: 0.2715
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.8083 - loss: 0.5238 - val_accuracy: 0.7500 - val_loss: 0.8185
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9583 - loss: 0.0871 - val_accuracy: 1.0000 - val_loss: 0.1285
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.9917 - loss: 0.0491 - val_accuracy: 0.8750 - val_loss: 0.1670
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 1.0000 - loss: 0.0316 - val_accuracy: 1.0000 - val_loss: 0.1295
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.9667 - loss: 0.0789 - val_accuracy: 0.8750 - val_loss: 0.1830
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9917 - loss: 0.0271 - val_accuracy: 0.8750 - val_loss: 0.1910
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9750 - loss: 0.0437 - val_accuracy: 0.7500 - val_loss: 0.7974
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0256 - val_accuracy: 0.8750 - val_loss: 0.2361
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.8750 - val_loss: 0.1770
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.8750 - val_loss: 0.1484
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.8750 - val_loss: 0.1862
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.8750 - val_loss: 0.1537
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.8750 - val_loss: 0.1983
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.1373
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.8750 - val_loss: 0.1462
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.1388
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.8750 - val_loss: 0.2202
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.8750 - val_loss: 0.1570
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8750 - val_loss: 0.1887
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.8750 - val_loss: 0.1941
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.8750 - val_loss: 0.1756
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.8750 - val_loss: 0.2196
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.8750 - val_loss: 0.1762
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8750 - val_loss: 0.1800
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.8750 - val_loss: 0.1951
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8750 - val_loss: 0.1978
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8750 - val_loss: 0.2964
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8750 - val_loss: 0.1516
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8750 - val_loss: 0.2014
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8750 - val_loss: 0.1974
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8750 - val_loss: 0.1715
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.1425
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8750 - val_loss: 0.2093
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8750 - val_loss: 0.1922
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8750 - val_loss: 0.2169
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8750 - val_loss: 0.2399
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8750 - val_loss: 0.1865
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8750 - val_loss: 0.1635
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8750 - val_loss: 0.2536
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8750 - val_loss: 0.1757
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8750 - val_loss: 0.2486
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8750 - val_loss: 0.1892
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8750 - val_loss: 0.2083
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8750 - val_loss: 0.2039
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8750 - val_loss: 0.2457
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.8750 - val_loss: 0.2034
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8750 - val_loss: 0.2201
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8750 - val_loss: 0.2468
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8750 - val_loss: 0.2284
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8750 - val_loss: 0.1942
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8750 - val_loss: 0.2310
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8750 - val_loss: 0.2086
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8750 - val_loss: 0.2423
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8750 - val_loss: 0.2213
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8750 - val_loss: 0.2337
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8750 - val_loss: 0.1857
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8750 - val_loss: 0.2265
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8750 - val_loss: 0.2133
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8750 - val_loss: 0.1963
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8750 - val_loss: 0.2224

# %% [markdown]
# **9. Model saving**

# %%
model.save('covid_classification.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# **10. Model loading**

# %%
from tensorflow.keras import models
model = models.load_model('covid_classification.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# **11. Model weights saving**

# %%
model.save_weights('covid_classification_weights.weights.h5')

# %% [markdown]
# **12. Model weights loading**

# %%
model.load_weights('covid_classification_weights.weights.h5')

# %% [markdown]
# **13. Plotting accuracy and loss graph for training and validation dataset**

# %%
train_acc = history.history['accuracy'] # Change 'acc' to 'accuracy'
val_acc = history.history['val_accuracy'] # Change 'val_acc' to 'val_accuracy'
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
import matplotlib.pyplot as plt
epochs = range(len(train_acc))
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.show()

plt.plot(epochs, train_loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# **14. Evaluate model performance on test dataset**

# %%
test_output = model.evaluate(
    test_generator,
    steps=int(test_generator.samples / test_generator.batch_size),  # Convert steps to an integer
    verbose=1
)
print(test_output)
print(model.metrics_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 568ms/step - accuracy: 0.6250 - loss: 2.2170
# [2.217034339904785, 0.625]
# ['loss', 'compile_metrics']

# %% [markdown]
# References:
#
# 1. https://pypi.org/project/split-folders/
# 2. https://keras.io/
