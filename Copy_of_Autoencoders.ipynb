# %%
from keras.layers import Input, Dense
from keras.models import Model

# this is the size of our encoded representations
encoding_dim = 256  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)

# %%
# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)

# %%
# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))
# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='RMSprop', loss='binary_crossentropy')

# %%
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print (x_train.shape)
print (x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
autoencoder.fit(x_train, x_train,
                epochs=68,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step - loss: 0.2618 - val_loss: 0.1954
# Epoch 2/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - loss: 0.1766 - val_loss: 0.1597
# Epoch 3/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.1506 - val_loss: 0.1402
# Epoch 4/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.1348 - val_loss: 0.1272
# Epoch 5/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.1234 - val_loss: 0.1172
# Epoch 6/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.1146 - val_loss: 0.1096
# Epoch 7/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 0.1076 - val_loss: 0.1032
# Epoch 8/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.1020 - val_loss: 0.0982
# Epoch 9/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0976 - val_loss: 0.0944
# Epoch 10/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0940 - val_loss: 0.0913
# Epoch 11/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - loss: 0.0912 - val_loss: 0.0888
# Epoch 12/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.0889 - val_loss: 0.0868
# Epoch 13/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0871 - val_loss: 0.0851
# Epoch 14/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0855 - val_loss: 0.0837
# Epoch 15/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0841 - val_loss: 0.0825
# Epoch 16/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0830 - val_loss: 0.0814
# Epoch 17/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0819 - val_loss: 0.0805
# Epoch 18/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0810 - val_loss: 0.0796
# Epoch 19/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - loss: 0.0802 - val_loss: 0.0789
# Epoch 20/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - loss: 0.0795 - val_loss: 0.0783
# Epoch 21/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0788 - val_loss: 0.0777
# Epoch 22/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0782 - val_loss: 0.0771
# Epoch 23/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0777 - val_loss: 0.0766
# Epoch 24/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0772 - val_loss: 0.0762
# Epoch 25/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - loss: 0.0767 - val_loss: 0.0757
# Epoch 26/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0763 - val_loss: 0.0753
# Epoch 27/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0759 - val_loss: 0.0750
# Epoch 28/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0755 - val_loss: 0.0747
# Epoch 29/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0752 - val_loss: 0.0743
# Epoch 30/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0749 - val_loss: 0.0740
# Epoch 31/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0746 - val_loss: 0.0737
# Epoch 32/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0743 - val_loss: 0.0735
# Epoch 33/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0740 - val_loss: 0.0732
# Epoch 34/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 0.0737 - val_loss: 0.0730
# Epoch 35/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 0.0735 - val_loss: 0.0728
# Epoch 36/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - loss: 0.0733 - val_loss: 0.0725
# Epoch 37/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0731 - val_loss: 0.0723
# Epoch 38/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0728 - val_loss: 0.0721
# Epoch 39/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0726 - val_loss: 0.0719
# Epoch 40/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0725 - val_loss: 0.0718
# Epoch 41/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 0.0723 - val_loss: 0.0716
# Epoch 42/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - loss: 0.0721 - val_loss: 0.0715
# Epoch 43/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0719 - val_loss: 0.0713
# Epoch 44/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0718 - val_loss: 0.0712
# Epoch 45/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.0716 - val_loss: 0.0710
# Epoch 46/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0715 - val_loss: 0.0709
# Epoch 47/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.0713 - val_loss: 0.0707
# Epoch 48/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0712 - val_loss: 0.0706
# Epoch 49/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0711 - val_loss: 0.0705
# Epoch 50/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.0710 - val_loss: 0.0704
# Epoch 51/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.0708 - val_loss: 0.0703
# Epoch 52/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0707 - val_loss: 0.0702
# Epoch 53/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0706 - val_loss: 0.0701
# Epoch 54/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.0705 - val_loss: 0.0700
# Epoch 55/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - loss: 0.0704 - val_loss: 0.0699
# Epoch 56/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0703 - val_loss: 0.0698
# Epoch 57/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 0.0702 - val_loss: 0.0697
# Epoch 58/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - loss: 0.0701 - val_loss: 0.0696
# Epoch 59/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0700 - val_loss: 0.0695
# Epoch 60/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0699 - val_loss: 0.0694
# Epoch 61/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 0.0698 - val_loss: 0.0693
# Epoch 62/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0697 - val_loss: 0.0693
# Epoch 63/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - loss: 0.0697 - val_loss: 0.0692
# Epoch 64/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.0696 - val_loss: 0.0691
# Epoch 65/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - loss: 0.0695 - val_loss: 0.0690
# Epoch 66/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0694 - val_loss: 0.0690
# Epoch 67/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 0.0693 - val_loss: 0.0689
# Epoch 68/68
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - loss: 0.0693 - val_loss: 0.0688

# %%
# encode and decode some digits
# note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
from keras.layers import Input, Dense
from keras.models import Model

# Define the size of the encoded representation
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# Input placeholder
input_img = Input(shape=(784,))

# Encoding layers
encoded = Dense(128, activation='relu')(input_img)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(encoding_dim, activation='relu')(encoded)

# Decoding layers
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(decoded)
decoded = Dense(784, activation='sigmoid')(decoded)

# Autoencoder model
autoencoder = Model(input_img, decoded)

# Encoder model
encoder = Model(input_img, encoded)

# Decoder model
encoded_input = Input(shape=(encoding_dim,))
decoder_layer1 = autoencoder.layers[-3]
decoder_layer2 = autoencoder.layers[-2]
decoder_layer3 = autoencoder.layers[-1]
decoder = Model(encoded_input, decoder_layer3(decoder_layer2(decoder_layer1(encoded_input))))

# %%
# Compile the model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the model
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 [==============================] - 6s 21ms/step - loss: 0.2449 - val_loss: 0.1670
# Epoch 2/50
# 235/235 [==============================] - 5s 22ms/step - loss: 0.1511 - val_loss: 0.1381
# Epoch 3/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.1333 - val_loss: 0.1263
# Epoch 4/50
# 235/235 [==============================] - 5s 19ms/step - loss: 0.1238 - val_loss: 0.1185
# Epoch 5/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.1171 - val_loss: 0.1144
# Epoch 6/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.1122 - val_loss: 0.1085
# Epoch 7/50
# 235/235 [==============================] - 7s 31ms/step - loss: 0.1085 - val_loss: 0.1055
# Epoch 8/50
# 235/235 [==============================] - 6s 25ms/step - loss: 0.1057 - val_loss: 0.1035
# Epoch 9/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.1037 - val_loss: 0.1019
# Epoch 10/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.1020 - val_loss: 0.0999
# Epoch 11/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1003 - val_loss: 0.0984
# Epoch 12/50
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0987 - val_loss: 0.0970
# Epoch 13/50
# 235/235 [==============================] - 6s 25ms/step - loss: 0.0975 - val_loss: 0.0961
# Epoch 14/50
# 235/235 [==============================] - 8s 34ms/step - loss: 0.0963 - val_loss: 0.0948
# Epoch 15/50
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0953 - val_loss: 0.0943
# Epoch 16/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0943 - val_loss: 0.0929
# Epoch 17/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0935 - val_loss: 0.0923
# Epoch 18/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0929 - val_loss: 0.0916
# Epoch 19/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0923 - val_loss: 0.0912
# Epoch 20/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0919 - val_loss: 0.0907
# Epoch 21/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0914 - val_loss: 0.0908
# Epoch 22/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0909 - val_loss: 0.0896
# Epoch 23/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0905 - val_loss: 0.0894
# Epoch 24/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0900 - val_loss: 0.0892
# Epoch 25/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0896 - val_loss: 0.0887
# Epoch 26/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0892 - val_loss: 0.0895
# Epoch 27/50
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0889 - val_loss: 0.0881
# Epoch 28/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0885 - val_loss: 0.0877
# Epoch 29/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0882 - val_loss: 0.0874
# Epoch 30/50
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0879 - val_loss: 0.0872
# Epoch 31/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0877 - val_loss: 0.0869
# Epoch 32/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0874 - val_loss: 0.0869
# Epoch 33/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0872 - val_loss: 0.0865
# Epoch 34/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0870 - val_loss: 0.0864
# Epoch 35/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0868 - val_loss: 0.0863
# Epoch 36/50
# 235/235 [==============================] - 4s 19ms/step - loss: 0.0866 - val_loss: 0.0859
# Epoch 37/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0864 - val_loss: 0.0858
# Epoch 38/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0863 - val_loss: 0.0857
# Epoch 39/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0861 - val_loss: 0.0853
# Epoch 40/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0860 - val_loss: 0.0859
# Epoch 41/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0858 - val_loss: 0.0854
# Epoch 42/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0857 - val_loss: 0.0851
# Epoch 43/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0855 - val_loss: 0.0850
# Epoch 44/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0853 - val_loss: 0.0847
# Epoch 45/50
# 235/235 [==============================] - 5s 21ms/step - loss: 0.0852 - val_loss: 0.0847
# Epoch 46/50
# 235/235 [==============================] - 5s 19ms/step - loss: 0.0851 - val_loss: 0.0843
# Epoch 47/50
# 235/235 [==============================] - 4s 17ms/step - loss: 0.0848 - val_loss: 0.0842
# Epoch 48/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0847 - val_loss: 0.0844
# Epoch 49/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.0845 - val_loss: 0.0840
# Epoch 50/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.0844 - val_loss: 0.0840

# %%
# encode and decode some digits
# note that we take them from the *test* set
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 1s 2ms/step

# %%
# use Matplotlib (don't ask)
import matplotlib.pyplot as plt

n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
